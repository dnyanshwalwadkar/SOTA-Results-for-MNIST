# %%
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist
# Out:
# 2024-08-05 15:53:33.481505: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-05 15:53:33.481617: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-05 15:53:33.615645: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Load the Fashion MNIST dataset
(train_data, train_labels), (test_data, test_labels) = fashion_mnist.load_data()

# Preprocess the data
train_data = train_data / 255.0
test_data = test_data / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
import numpy as np
from sklearn.utils.class_weight import compute_class_weight
# Calculate the class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_labels),
    y=train_labels
)

# Convert the class weights to a dictionary
class_weights_dict = {i: class_weights[i] for i in np.unique(train_labels)}

# %%
class_weights_dict
# Out:
# {0: 1.0,
#  1: 1.0,
#  2: 1.0,
#  3: 1.0,
#  4: 1.0,
#  5: 1.0,
#  6: 1.0,
#  7: 1.0,
#  8: 1.0,
#  9: 1.0}

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# Create a callback that saves the model with the best validation accuracy
checkpoint_callback = ModelCheckpoint(
    filepath='best_model.keras',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)

# %%
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
import tensorflow_datasets as tfds

# MobileMNIST model
def MobileMNIST(input_shape, num_classes, num_channels, dim, expansion_ratio, num_layers=[2, 4, 3]):
    inputs = layers.Input(input_shape)

    # Stem
    x = layers.Conv2D(filters=num_channels[0], kernel_size=3, strides=2, padding="same", use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)
    x = inverted_residual_block(x, num_channels[1], strides=1, expansion_ratio=expansion_ratio)

    # Stage 1
    x = inverted_residual_block(x, num_channels[2], strides=2, expansion_ratio=expansion_ratio)
    x = inverted_residual_block(x, num_channels[3], strides=1, expansion_ratio=expansion_ratio)
    skip_1 = inverted_residual_block(x, num_channels[4], strides=1, expansion_ratio=expansion_ratio)

    # Stage 2
    x = inverted_residual_block(skip_1, num_channels[5], strides=2, expansion_ratio=expansion_ratio)
    skip_2 = mobile_block(x, num_channels[6], dim[0], num_layers=num_layers[0])

    # Stage 3
    x = inverted_residual_block(skip_2, num_channels[7], strides=2, expansion_ratio=expansion_ratio)
    skip_3 = mobile_block(x, num_channels[8], dim[1], num_layers=num_layers[1])

    # Classification head
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(num_classes, activation='softmax', kernel_regularizer=regularizers.l2(0.01))(x)

    return models.Model(inputs, x)

# Define inverted residual block (assuming you already have this function)
def inverted_residual_block(inputs, num_filters, strides=1, expansion_ratio=1):
    x = layers.Conv2D(filters=expansion_ratio * inputs.shape[-1], kernel_size=1, padding="same", use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    x = layers.DepthwiseConv2D(kernel_size=3, strides=strides, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    x = layers.Conv2D(filters=num_filters, kernel_size=1, padding="same", use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    if strides == 1 and inputs.shape == x.shape:
        return layers.Add()([inputs, x])
    return x

# Define mobile vit block (assuming you already have this function)
def mobile_block(inputs, num_filters, dim, patch_size=2, num_layers=1):
    B, H, W, C = inputs.shape

    x = layers.SeparableConv2D(filters=num_filters, kernel_size=3, padding="same", use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("swish")(x)

    return x

# Define transformer encoder (assuming you already have this function)
def transformer_encoder(x, num_heads, dim, mlp_dim):
    skip_1 = x
    x = layers.LayerNormalization()(x)
    x = layers.MultiHeadAttention(num_heads=num_heads, key_dim=dim)(x, x)
    x = layers.Add()([x, skip_1])

    skip_2 = x
    x = layers.LayerNormalization()(x)
    x = mlp(x, mlp_dim, dim)
    x = layers.Add()([x, skip_2])

    return x

def mlp(x, mlp_dim, dim, dropout_rate=0.1):
    x = layers.Dense(mlp_dim, activation="swish")(x)
    x = layers.Dropout(dropout_rate)(x)
    x = layers.Dense(dim)(x)
    x = layers.Dropout(dropout_rate)(x)
    return x

# %%
input_shape = (28, 28,1)
num_classes = 10
model = MobileMNIST(input_shape, num_classes, num_channels=[16, 16, 24, 24, 24, 48, 64, 64, 80], dim=[64, 80, 96], expansion_ratio=2, num_layers=[2, 4, 3])

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 28, 28, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 14, 14,    │        144 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 14, 14,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 14, 14,    │        512 │ activation[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        128 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d    │ (None, 14, 14,    │        288 │ activation_1[0][… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 14, 14,    │        512 │ activation_2[0][… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 14, 14,    │          0 │ activation[0][0], │
# │                     │ 16)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 14, 14,    │        512 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 14, 14,    │        128 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 14, 14,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_1  │ (None, 7, 7, 32)  │        288 │ activation_3[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 32)  │        128 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 7, 7, 32)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 7, 7, 24)  │        768 │ activation_4[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 24)  │         96 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 7, 7, 48)  │      1,152 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 48)  │        192 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 7, 7, 48)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_2  │ (None, 7, 7, 48)  │        432 │ activation_5[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 48)  │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 7, 7, 48)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 7, 7, 24)  │      1,152 │ activation_6[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 24)  │         96 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 7, 7, 24)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 7, 7, 48)  │      1,152 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 48)  │        192 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 7, 7, 48)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_3  │ (None, 7, 7, 48)  │        432 │ activation_7[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 48)  │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 7, 7, 48)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 7, 7, 24)  │      1,152 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 24)  │         96 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_2 (Add)         │ (None, 7, 7, 24)  │          0 │ add_1[0][0],      │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 7, 7, 48)  │      1,152 │ add_2[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 7, 7, 48)  │        192 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 7, 7, 48)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_4  │ (None, 4, 4, 48)  │        432 │ activation_9[0][… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 48)  │        192 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 4, 4, 48)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 4, 4, 48)  │      2,304 │ activation_10[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 48)  │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 4, 4, 64)  │      3,504 │ batch_normalizat… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 64)  │        256 │ separable_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 4, 4, 64)  │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 4, 4, 128) │      8,192 │ activation_11[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 128) │        512 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 4, 4, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_5  │ (None, 2, 2, 128) │      1,152 │ activation_12[0]… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 128) │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 2, 2, 128) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 2, 2, 64)  │      8,192 │ activation_13[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 64)  │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 10)        │        650 │ global_average_p… │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 37,882 (147.98 KB)
#  Trainable params: 35,978 (140.54 KB)
#  Non-trainable params: 1,904 (7.44 KB)

# %%
def softmax_loss(y_true, y_pred):
    """
    Custom softmax loss function.

    :param y_true: Sparse target labels.
    :param y_pred: Logits.
    :return: Computed loss value.
    """
    y_true = tf.cast(tf.reshape(y_true, [-1]), tf.int32)
    ce = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y_true, logits=y_pred)
    return tf.reduce_mean(ce)

loss = softmax_loss

model.compile(loss = loss,
                    optimizer = tf.keras.optimizers.Adam(),
                    metrics = ['accuracy'])

# %%
history = model.fit(train_data , train_labels , epochs = 150 , validation_data = (test_data ,test_labels),class_weight=class_weights_dict,callbacks=[checkpoint_callback])
# Out:
# Epoch 1/150
#   28/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.2400 - loss: 2.3992
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722873248.282743      82 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7363 - loss: 1.8217
# Epoch 1: val_accuracy improved from -inf to 0.85870, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 33s 8ms/step - accuracy: 0.7363 - loss: 1.8217 - val_accuracy: 0.8587 - val_loss: 1.6388
# Epoch 2/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8651 - loss: 1.6297
# Epoch 2: val_accuracy did not improve from 0.85870
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8651 - loss: 1.6296 - val_accuracy: 0.8532 - val_loss: 1.6289
# Epoch 3/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8777 - loss: 1.6046
# Epoch 3: val_accuracy improved from 0.85870 to 0.86170, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8777 - loss: 1.6046 - val_accuracy: 0.8617 - val_loss: 1.6166
# Epoch 4/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8819 - loss: 1.5953
# Epoch 4: val_accuracy improved from 0.86170 to 0.86460, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8819 - loss: 1.5953 - val_accuracy: 0.8646 - val_loss: 1.6086
# Epoch 5/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8851 - loss: 1.5885
# Epoch 5: val_accuracy improved from 0.86460 to 0.87260, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8851 - loss: 1.5885 - val_accuracy: 0.8726 - val_loss: 1.5990
# Epoch 6/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8898 - loss: 1.5822
# Epoch 6: val_accuracy improved from 0.87260 to 0.88250, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8898 - loss: 1.5822 - val_accuracy: 0.8825 - val_loss: 1.5880
# Epoch 7/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8966 - loss: 1.5738
# Epoch 7: val_accuracy improved from 0.88250 to 0.88420, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8966 - loss: 1.5738 - val_accuracy: 0.8842 - val_loss: 1.5853
# Epoch 8/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8950 - loss: 1.5743
# Epoch 8: val_accuracy improved from 0.88420 to 0.88580, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8950 - loss: 1.5743 - val_accuracy: 0.8858 - val_loss: 1.5825
# Epoch 9/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8985 - loss: 1.5702
# Epoch 9: val_accuracy improved from 0.88580 to 0.88640, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.8985 - loss: 1.5702 - val_accuracy: 0.8864 - val_loss: 1.5822
# Epoch 10/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9010 - loss: 1.5673
# Epoch 10: val_accuracy did not improve from 0.88640
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9010 - loss: 1.5673 - val_accuracy: 0.8860 - val_loss: 1.5820
# Epoch 11/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9039 - loss: 1.5635
# Epoch 11: val_accuracy did not improve from 0.88640
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9039 - loss: 1.5635 - val_accuracy: 0.8744 - val_loss: 1.5920
# Epoch 12/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9020 - loss: 1.5655
# Epoch 12: val_accuracy improved from 0.88640 to 0.88710, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9020 - loss: 1.5655 - val_accuracy: 0.8871 - val_loss: 1.5803
# Epoch 13/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9039 - loss: 1.5632
# Epoch 13: val_accuracy did not improve from 0.88710
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9039 - loss: 1.5632 - val_accuracy: 0.8859 - val_loss: 1.5804
# Epoch 14/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9066 - loss: 1.5603
# Epoch 14: val_accuracy did not improve from 0.88710
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9066 - loss: 1.5603 - val_accuracy: 0.8852 - val_loss: 1.5809
# Epoch 15/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9072 - loss: 1.5596
# Epoch 15: val_accuracy improved from 0.88710 to 0.89370, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9072 - loss: 1.5596 - val_accuracy: 0.8937 - val_loss: 1.5715
# Epoch 16/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9111 - loss: 1.5559
# Epoch 16: val_accuracy did not improve from 0.89370
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9111 - loss: 1.5559 - val_accuracy: 0.8886 - val_loss: 1.5772
# Epoch 17/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9083 - loss: 1.5576
# Epoch 17: val_accuracy did not improve from 0.89370
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9083 - loss: 1.5576 - val_accuracy: 0.8918 - val_loss: 1.5737
# Epoch 18/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9098 - loss: 1.5564
# Epoch 18: val_accuracy improved from 0.89370 to 0.89680, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9098 - loss: 1.5564 - val_accuracy: 0.8968 - val_loss: 1.5688
# Epoch 19/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9092 - loss: 1.5568
# Epoch 19: val_accuracy did not improve from 0.89680
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9092 - loss: 1.5568 - val_accuracy: 0.8951 - val_loss: 1.5699
# Epoch 20/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9143 - loss: 1.5517
# Epoch 20: val_accuracy did not improve from 0.89680
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9143 - loss: 1.5517 - val_accuracy: 0.8954 - val_loss: 1.5696
# Epoch 21/150
# 1872/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9139 - loss: 1.5524
# Epoch 21: val_accuracy did not improve from 0.89680
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9139 - loss: 1.5524 - val_accuracy: 0.8952 - val_loss: 1.5703
# Epoch 22/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9148 - loss: 1.5512
# Epoch 22: val_accuracy improved from 0.89680 to 0.89810, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9148 - loss: 1.5512 - val_accuracy: 0.8981 - val_loss: 1.5666
# Epoch 23/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9153 - loss: 1.5508
# Epoch 23: val_accuracy did not improve from 0.89810
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9153 - loss: 1.5508 - val_accuracy: 0.8944 - val_loss: 1.5709
# Epoch 24/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9148 - loss: 1.5507
# Epoch 24: val_accuracy did not improve from 0.89810
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9148 - loss: 1.5507 - val_accuracy: 0.8830 - val_loss: 1.5819
# Epoch 25/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9151 - loss: 1.5500
# Epoch 25: val_accuracy did not improve from 0.89810
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9151 - loss: 1.5500 - val_accuracy: 0.8969 - val_loss: 1.5672
# Epoch 26/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9176 - loss: 1.5481
# Epoch 26: val_accuracy did not improve from 0.89810
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9176 - loss: 1.5481 - val_accuracy: 0.8926 - val_loss: 1.5724
# Epoch 27/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9221 - loss: 1.5437
# Epoch 27: val_accuracy did not improve from 0.89810
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9221 - loss: 1.5437 - val_accuracy: 0.8909 - val_loss: 1.5735
# Epoch 28/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9192 - loss: 1.5458
# Epoch 28: val_accuracy improved from 0.89810 to 0.89910, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9192 - loss: 1.5458 - val_accuracy: 0.8991 - val_loss: 1.5659
# Epoch 29/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9171 - loss: 1.5480
# Epoch 29: val_accuracy did not improve from 0.89910
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9171 - loss: 1.5480 - val_accuracy: 0.8954 - val_loss: 1.5690
# Epoch 30/150
# 1872/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9190 - loss: 1.5458
# Epoch 30: val_accuracy improved from 0.89910 to 0.90110, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9190 - loss: 1.5458 - val_accuracy: 0.9011 - val_loss: 1.5638
# Epoch 31/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9216 - loss: 1.5437
# Epoch 31: val_accuracy did not improve from 0.90110
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9216 - loss: 1.5437 - val_accuracy: 0.8960 - val_loss: 1.5681
# Epoch 32/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9218 - loss: 1.5429
# Epoch 32: val_accuracy improved from 0.90110 to 0.90270, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9218 - loss: 1.5429 - val_accuracy: 0.9027 - val_loss: 1.5624
# Epoch 33/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9208 - loss: 1.5440
# Epoch 33: val_accuracy improved from 0.90270 to 0.90380, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9208 - loss: 1.5440 - val_accuracy: 0.9038 - val_loss: 1.5615
# Epoch 34/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9234 - loss: 1.5419
# Epoch 34: val_accuracy did not improve from 0.90380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9234 - loss: 1.5419 - val_accuracy: 0.9024 - val_loss: 1.5619
# Epoch 35/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9220 - loss: 1.5431
# Epoch 35: val_accuracy did not improve from 0.90380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9220 - loss: 1.5431 - val_accuracy: 0.8951 - val_loss: 1.5700
# Epoch 36/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9243 - loss: 1.5406
# Epoch 36: val_accuracy did not improve from 0.90380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9243 - loss: 1.5406 - val_accuracy: 0.9038 - val_loss: 1.5610
# Epoch 37/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9271 - loss: 1.5376
# Epoch 37: val_accuracy did not improve from 0.90380
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9271 - loss: 1.5376 - val_accuracy: 0.9016 - val_loss: 1.5642
# Epoch 38/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9261 - loss: 1.5389
# Epoch 38: val_accuracy improved from 0.90380 to 0.90570, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9261 - loss: 1.5389 - val_accuracy: 0.9057 - val_loss: 1.5595
# Epoch 39/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9223 - loss: 1.5426
# Epoch 39: val_accuracy did not improve from 0.90570
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9223 - loss: 1.5426 - val_accuracy: 0.8981 - val_loss: 1.5664
# Epoch 40/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9263 - loss: 1.5388
# Epoch 40: val_accuracy did not improve from 0.90570
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9263 - loss: 1.5388 - val_accuracy: 0.9042 - val_loss: 1.5597
# Epoch 41/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9280 - loss: 1.5371
# Epoch 41: val_accuracy did not improve from 0.90570
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9280 - loss: 1.5371 - val_accuracy: 0.9018 - val_loss: 1.5623
# Epoch 42/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9259 - loss: 1.5389
# Epoch 42: val_accuracy improved from 0.90570 to 0.90800, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9259 - loss: 1.5389 - val_accuracy: 0.9080 - val_loss: 1.5563
# Epoch 43/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9274 - loss: 1.5370
# Epoch 43: val_accuracy did not improve from 0.90800
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9274 - loss: 1.5370 - val_accuracy: 0.9070 - val_loss: 1.5574
# Epoch 44/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9310 - loss: 1.5337
# Epoch 44: val_accuracy did not improve from 0.90800
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9310 - loss: 1.5337 - val_accuracy: 0.9065 - val_loss: 1.5572
# Epoch 45/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9292 - loss: 1.5355
# Epoch 45: val_accuracy improved from 0.90800 to 0.90810, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9292 - loss: 1.5355 - val_accuracy: 0.9081 - val_loss: 1.5564
# Epoch 46/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9299 - loss: 1.5350
# Epoch 46: val_accuracy did not improve from 0.90810
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9299 - loss: 1.5350 - val_accuracy: 0.9072 - val_loss: 1.5573
# Epoch 47/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9272 - loss: 1.5371
# Epoch 47: val_accuracy improved from 0.90810 to 0.90930, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9272 - loss: 1.5371 - val_accuracy: 0.9093 - val_loss: 1.5545
# Epoch 48/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9324 - loss: 1.5322
# Epoch 48: val_accuracy did not improve from 0.90930
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9324 - loss: 1.5322 - val_accuracy: 0.9049 - val_loss: 1.5596
# Epoch 49/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9318 - loss: 1.5330
# Epoch 49: val_accuracy did not improve from 0.90930
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9318 - loss: 1.5330 - val_accuracy: 0.9066 - val_loss: 1.5581
# Epoch 50/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9311 - loss: 1.5334
# Epoch 50: val_accuracy did not improve from 0.90930
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9311 - loss: 1.5334 - val_accuracy: 0.9063 - val_loss: 1.5582
# Epoch 51/150
# 1872/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9286 - loss: 1.5357
# Epoch 51: val_accuracy did not improve from 0.90930
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9286 - loss: 1.5357 - val_accuracy: 0.9085 - val_loss: 1.5567
# Epoch 52/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9321 - loss: 1.5326
# Epoch 52: val_accuracy did not improve from 0.90930
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9321 - loss: 1.5326 - val_accuracy: 0.9017 - val_loss: 1.5623
# Epoch 53/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9318 - loss: 1.5327
# Epoch 53: val_accuracy did not improve from 0.90930
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9318 - loss: 1.5327 - val_accuracy: 0.8998 - val_loss: 1.5648
# Epoch 54/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9323 - loss: 1.5327
# Epoch 54: val_accuracy improved from 0.90930 to 0.91020, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9323 - loss: 1.5327 - val_accuracy: 0.9102 - val_loss: 1.5540
# Epoch 55/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9334 - loss: 1.5312
# Epoch 55: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9334 - loss: 1.5312 - val_accuracy: 0.8956 - val_loss: 1.5683
# Epoch 56/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9323 - loss: 1.5321
# Epoch 56: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9323 - loss: 1.5321 - val_accuracy: 0.9034 - val_loss: 1.5612
# Epoch 57/150
# 1872/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9306 - loss: 1.5338
# Epoch 57: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9306 - loss: 1.5338 - val_accuracy: 0.9016 - val_loss: 1.5625
# Epoch 58/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9336 - loss: 1.5311
# Epoch 58: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9336 - loss: 1.5311 - val_accuracy: 0.9071 - val_loss: 1.5572
# Epoch 59/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9337 - loss: 1.5307
# Epoch 59: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9337 - loss: 1.5307 - val_accuracy: 0.9097 - val_loss: 1.5547
# Epoch 60/150
# 1871/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9335 - loss: 1.5311
# Epoch 60: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9335 - loss: 1.5311 - val_accuracy: 0.9093 - val_loss: 1.5552
# Epoch 61/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9325 - loss: 1.5320
# Epoch 61: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9325 - loss: 1.5320 - val_accuracy: 0.9047 - val_loss: 1.5596
# Epoch 62/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9345 - loss: 1.5299
# Epoch 62: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9345 - loss: 1.5299 - val_accuracy: 0.9054 - val_loss: 1.5589
# Epoch 63/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9330 - loss: 1.5312
# Epoch 63: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9330 - loss: 1.5312 - val_accuracy: 0.9038 - val_loss: 1.5608
# Epoch 64/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9351 - loss: 1.5293
# Epoch 64: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9351 - loss: 1.5293 - val_accuracy: 0.9009 - val_loss: 1.5636
# Epoch 65/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9340 - loss: 1.5306
# Epoch 65: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9340 - loss: 1.5306 - val_accuracy: 0.9029 - val_loss: 1.5618
# Epoch 66/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9324 - loss: 1.5322
# Epoch 66: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9324 - loss: 1.5322 - val_accuracy: 0.9069 - val_loss: 1.5571
# Epoch 67/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9365 - loss: 1.5280
# Epoch 67: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9365 - loss: 1.5280 - val_accuracy: 0.9085 - val_loss: 1.5556
# Epoch 68/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9377 - loss: 1.5266
# Epoch 68: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9377 - loss: 1.5266 - val_accuracy: 0.9056 - val_loss: 1.5580
# Epoch 69/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9380 - loss: 1.5265
# Epoch 69: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9380 - loss: 1.5265 - val_accuracy: 0.9052 - val_loss: 1.5585
# Epoch 70/150
# 1872/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9373 - loss: 1.5270
# Epoch 70: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9373 - loss: 1.5270 - val_accuracy: 0.9017 - val_loss: 1.5619
# Epoch 71/150
# 1872/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9351 - loss: 1.5294
# Epoch 71: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9351 - loss: 1.5294 - val_accuracy: 0.9079 - val_loss: 1.5559
# Epoch 72/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9386 - loss: 1.5258
# Epoch 72: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 6ms/step - accuracy: 0.9386 - loss: 1.5258 - val_accuracy: 0.9082 - val_loss: 1.5563
# Epoch 73/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9381 - loss: 1.5265
# Epoch 73: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9381 - loss: 1.5265 - val_accuracy: 0.9062 - val_loss: 1.5571
# Epoch 74/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9362 - loss: 1.5278
# Epoch 74: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9362 - loss: 1.5278 - val_accuracy: 0.9074 - val_loss: 1.5561
# Epoch 75/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9381 - loss: 1.5263
# Epoch 75: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9381 - loss: 1.5263 - val_accuracy: 0.9087 - val_loss: 1.5556
# Epoch 76/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9405 - loss: 1.5236
# Epoch 76: val_accuracy did not improve from 0.91020
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9405 - loss: 1.5236 - val_accuracy: 0.9100 - val_loss: 1.5539
# Epoch 77/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9390 - loss: 1.5254
# Epoch 77: val_accuracy improved from 0.91020 to 0.91170, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9390 - loss: 1.5254 - val_accuracy: 0.9117 - val_loss: 1.5521
# Epoch 78/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9409 - loss: 1.5235
# Epoch 78: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9409 - loss: 1.5235 - val_accuracy: 0.9100 - val_loss: 1.5532
# Epoch 79/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9391 - loss: 1.5252
# Epoch 79: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9391 - loss: 1.5252 - val_accuracy: 0.9070 - val_loss: 1.5573
# Epoch 80/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9412 - loss: 1.5234
# Epoch 80: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9412 - loss: 1.5234 - val_accuracy: 0.9104 - val_loss: 1.5541
# Epoch 81/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9389 - loss: 1.5255
# Epoch 81: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9389 - loss: 1.5255 - val_accuracy: 0.9097 - val_loss: 1.5548
# Epoch 82/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9404 - loss: 1.5241
# Epoch 82: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9404 - loss: 1.5241 - val_accuracy: 0.9116 - val_loss: 1.5529
# Epoch 83/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9380 - loss: 1.5259
# Epoch 83: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9380 - loss: 1.5259 - val_accuracy: 0.8986 - val_loss: 1.5654
# Epoch 84/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9395 - loss: 1.5248
# Epoch 84: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9395 - loss: 1.5248 - val_accuracy: 0.9085 - val_loss: 1.5555
# Epoch 85/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9412 - loss: 1.5234
# Epoch 85: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9412 - loss: 1.5234 - val_accuracy: 0.9116 - val_loss: 1.5521
# Epoch 86/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9408 - loss: 1.5235
# Epoch 86: val_accuracy did not improve from 0.91170
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9408 - loss: 1.5235 - val_accuracy: 0.9113 - val_loss: 1.5531
# Epoch 87/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9409 - loss: 1.5236
# Epoch 87: val_accuracy improved from 0.91170 to 0.91320, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9409 - loss: 1.5236 - val_accuracy: 0.9132 - val_loss: 1.5510
# Epoch 88/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9407 - loss: 1.5234
# Epoch 88: val_accuracy did not improve from 0.91320
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9407 - loss: 1.5234 - val_accuracy: 0.8966 - val_loss: 1.5674
# Epoch 89/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9399 - loss: 1.5244
# Epoch 89: val_accuracy did not improve from 0.91320
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9399 - loss: 1.5244 - val_accuracy: 0.9104 - val_loss: 1.5539
# Epoch 90/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9426 - loss: 1.5216
# Epoch 90: val_accuracy did not improve from 0.91320
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9426 - loss: 1.5216 - val_accuracy: 0.9066 - val_loss: 1.5575
# Epoch 91/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9452 - loss: 1.5193
# Epoch 91: val_accuracy did not improve from 0.91320
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9452 - loss: 1.5193 - val_accuracy: 0.9082 - val_loss: 1.5554
# Epoch 92/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9393 - loss: 1.5252
# Epoch 92: val_accuracy did not improve from 0.91320
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9393 - loss: 1.5251 - val_accuracy: 0.9082 - val_loss: 1.5559
# Epoch 93/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9414 - loss: 1.5226
# Epoch 93: val_accuracy did not improve from 0.91320
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9414 - loss: 1.5226 - val_accuracy: 0.9117 - val_loss: 1.5525
# Epoch 94/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9432 - loss: 1.5211
# Epoch 94: val_accuracy did not improve from 0.91320
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9432 - loss: 1.5211 - val_accuracy: 0.9095 - val_loss: 1.5544
# Epoch 95/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9426 - loss: 1.5212
# Epoch 95: val_accuracy improved from 0.91320 to 0.91370, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9426 - loss: 1.5212 - val_accuracy: 0.9137 - val_loss: 1.5493
# Epoch 96/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9429 - loss: 1.5214
# Epoch 96: val_accuracy did not improve from 0.91370
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9429 - loss: 1.5214 - val_accuracy: 0.9056 - val_loss: 1.5579
# Epoch 97/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9422 - loss: 1.5220
# Epoch 97: val_accuracy improved from 0.91370 to 0.91590, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9422 - loss: 1.5220 - val_accuracy: 0.9159 - val_loss: 1.5481
# Epoch 98/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9467 - loss: 1.5178
# Epoch 98: val_accuracy did not improve from 0.91590
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9467 - loss: 1.5178 - val_accuracy: 0.9143 - val_loss: 1.5495
# Epoch 99/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9454 - loss: 1.5188
# Epoch 99: val_accuracy did not improve from 0.91590
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9454 - loss: 1.5188 - val_accuracy: 0.9119 - val_loss: 1.5522
# Epoch 100/150
# 1871/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9446 - loss: 1.5196
# Epoch 100: val_accuracy did not improve from 0.91590
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9446 - loss: 1.5196 - val_accuracy: 0.9100 - val_loss: 1.5535
# Epoch 101/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9442 - loss: 1.5199
# Epoch 101: val_accuracy did not improve from 0.91590
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9442 - loss: 1.5199 - val_accuracy: 0.9127 - val_loss: 1.5509
# Epoch 102/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9454 - loss: 1.5189
# Epoch 102: val_accuracy did not improve from 0.91590
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9454 - loss: 1.5189 - val_accuracy: 0.9097 - val_loss: 1.5541
# Epoch 103/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9466 - loss: 1.5176
# Epoch 103: val_accuracy did not improve from 0.91590
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9466 - loss: 1.5176 - val_accuracy: 0.9143 - val_loss: 1.5501
# Epoch 104/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9459 - loss: 1.5185
# Epoch 104: val_accuracy improved from 0.91590 to 0.91600, saving model to best_model.keras
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9459 - loss: 1.5185 - val_accuracy: 0.9160 - val_loss: 1.5484
# Epoch 105/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9473 - loss: 1.5171
# Epoch 105: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9473 - loss: 1.5171 - val_accuracy: 0.9073 - val_loss: 1.5567
# Epoch 106/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9456 - loss: 1.5186
# Epoch 106: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9456 - loss: 1.5186 - val_accuracy: 0.9075 - val_loss: 1.5570
# Epoch 107/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9439 - loss: 1.5207
# Epoch 107: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9439 - loss: 1.5207 - val_accuracy: 0.9129 - val_loss: 1.5510
# Epoch 108/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9456 - loss: 1.5186
# Epoch 108: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9456 - loss: 1.5186 - val_accuracy: 0.9104 - val_loss: 1.5536
# Epoch 109/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9501 - loss: 1.5141
# Epoch 109: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9501 - loss: 1.5141 - val_accuracy: 0.9119 - val_loss: 1.5520
# Epoch 110/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9490 - loss: 1.5150
# Epoch 110: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9490 - loss: 1.5150 - val_accuracy: 0.9109 - val_loss: 1.5530
# Epoch 111/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9496 - loss: 1.5147
# Epoch 111: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9496 - loss: 1.5147 - val_accuracy: 0.9110 - val_loss: 1.5526
# Epoch 112/150
# 1872/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9484 - loss: 1.5157
# Epoch 112: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9484 - loss: 1.5157 - val_accuracy: 0.9109 - val_loss: 1.5532
# Epoch 113/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9476 - loss: 1.5168
# Epoch 113: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9476 - loss: 1.5168 - val_accuracy: 0.9129 - val_loss: 1.5505
# Epoch 114/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9500 - loss: 1.5140
# Epoch 114: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9500 - loss: 1.5140 - val_accuracy: 0.9097 - val_loss: 1.5537
# Epoch 115/150
# 1871/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9496 - loss: 1.5148
# Epoch 115: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9496 - loss: 1.5148 - val_accuracy: 0.9125 - val_loss: 1.5511
# Epoch 116/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9495 - loss: 1.5145
# Epoch 116: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9495 - loss: 1.5145 - val_accuracy: 0.9135 - val_loss: 1.5507
# Epoch 117/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9492 - loss: 1.5149
# Epoch 117: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9492 - loss: 1.5149 - val_accuracy: 0.9096 - val_loss: 1.5542
# Epoch 118/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9478 - loss: 1.5164
# Epoch 118: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9478 - loss: 1.5164 - val_accuracy: 0.8995 - val_loss: 1.5644
# Epoch 119/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9489 - loss: 1.5152
# Epoch 119: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9489 - loss: 1.5152 - val_accuracy: 0.9093 - val_loss: 1.5547
# Epoch 120/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9505 - loss: 1.5141
# Epoch 120: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9505 - loss: 1.5141 - val_accuracy: 0.9067 - val_loss: 1.5566
# Epoch 121/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9516 - loss: 1.5126
# Epoch 121: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9516 - loss: 1.5126 - val_accuracy: 0.9070 - val_loss: 1.5572
# Epoch 122/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9506 - loss: 1.5135
# Epoch 122: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9506 - loss: 1.5135 - val_accuracy: 0.9104 - val_loss: 1.5528
# Epoch 123/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9507 - loss: 1.5135
# Epoch 123: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9507 - loss: 1.5135 - val_accuracy: 0.9095 - val_loss: 1.5545
# Epoch 124/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9503 - loss: 1.5142
# Epoch 124: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9503 - loss: 1.5142 - val_accuracy: 0.9066 - val_loss: 1.5587
# Epoch 125/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9520 - loss: 1.5125
# Epoch 125: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9520 - loss: 1.5125 - val_accuracy: 0.9130 - val_loss: 1.5514
# Epoch 126/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9514 - loss: 1.5130
# Epoch 126: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9514 - loss: 1.5130 - val_accuracy: 0.9115 - val_loss: 1.5521
# Epoch 127/150
# 1870/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9507 - loss: 1.5133
# Epoch 127: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9507 - loss: 1.5133 - val_accuracy: 0.9088 - val_loss: 1.5557
# Epoch 128/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9511 - loss: 1.5130
# Epoch 128: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9511 - loss: 1.5130 - val_accuracy: 0.9115 - val_loss: 1.5530
# Epoch 129/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9501 - loss: 1.5142
# Epoch 129: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9501 - loss: 1.5142 - val_accuracy: 0.9133 - val_loss: 1.5511
# Epoch 130/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9521 - loss: 1.5121
# Epoch 130: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9521 - loss: 1.5121 - val_accuracy: 0.9139 - val_loss: 1.5500
# Epoch 131/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9515 - loss: 1.5126
# Epoch 131: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9515 - loss: 1.5126 - val_accuracy: 0.9085 - val_loss: 1.5554
# Epoch 132/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9526 - loss: 1.5115
# Epoch 132: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9526 - loss: 1.5115 - val_accuracy: 0.9103 - val_loss: 1.5530
# Epoch 133/150
# 1871/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9525 - loss: 1.5117
# Epoch 133: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9524 - loss: 1.5117 - val_accuracy: 0.9089 - val_loss: 1.5545
# Epoch 134/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9536 - loss: 1.5107
# Epoch 134: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9536 - loss: 1.5107 - val_accuracy: 0.9106 - val_loss: 1.5532
# Epoch 135/150
# 1867/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9530 - loss: 1.5114
# Epoch 135: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9530 - loss: 1.5114 - val_accuracy: 0.9132 - val_loss: 1.5509
# Epoch 136/150
# 1873/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9504 - loss: 1.5137
# Epoch 136: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9504 - loss: 1.5137 - val_accuracy: 0.9138 - val_loss: 1.5502
# Epoch 137/150
# 1874/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9544 - loss: 1.5098
# Epoch 137: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9544 - loss: 1.5098 - val_accuracy: 0.9134 - val_loss: 1.5509
# Epoch 138/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9534 - loss: 1.5109
# Epoch 138: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9534 - loss: 1.5109 - val_accuracy: 0.9135 - val_loss: 1.5499
# Epoch 139/150
# 1872/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9519 - loss: 1.5122
# Epoch 139: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9519 - loss: 1.5122 - val_accuracy: 0.9085 - val_loss: 1.5552
# Epoch 140/150
# 1868/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9510 - loss: 1.5131
# Epoch 140: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9511 - loss: 1.5131 - val_accuracy: 0.9125 - val_loss: 1.5518
# Epoch 141/150
# 1866/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9532 - loss: 1.5111
# Epoch 141: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9532 - loss: 1.5111 - val_accuracy: 0.9119 - val_loss: 1.5521
# Epoch 142/150
# 1871/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9513 - loss: 1.5132
# Epoch 142: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9513 - loss: 1.5132 - val_accuracy: 0.9139 - val_loss: 1.5501
# Epoch 143/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9542 - loss: 1.5101
# Epoch 143: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - accuracy: 0.9542 - loss: 1.5101 - val_accuracy: 0.9061 - val_loss: 1.5579
# Epoch 144/150
# 1871/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9530 - loss: 1.5108
# Epoch 144: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9530 - loss: 1.5108 - val_accuracy: 0.9096 - val_loss: 1.5541
# Epoch 145/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9550 - loss: 1.5088
# Epoch 145: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9550 - loss: 1.5088 - val_accuracy: 0.9109 - val_loss: 1.5528
# Epoch 146/150
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9538 - loss: 1.5100
# Epoch 146: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9538 - loss: 1.5100 - val_accuracy: 0.9142 - val_loss: 1.5492
# Epoch 147/150
# 1869/1875 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9541 - loss: 1.5101
# Epoch 147: val_accuracy did not improve from 0.91600
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.9541 - loss: 1.5100 - val_accuracy: 0.9125 - val_loss: 1.5507
# Epoch 148/150
# 1260/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.9554 - loss: 1.5089

# %%
# Convert the history to a DataFrame
history_df = pd.DataFrame(history.history)

# Plot the loss
plt.figure(figsize=(10, 5))
plt.plot(history_df['loss'], label='Training Loss')
plt.plot(history_df['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# Plot the accuracy
plt.figure(figsize=(10, 5))
plt.plot(history_df['accuracy'], label='Training Accuracy')
plt.plot(history_df['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
